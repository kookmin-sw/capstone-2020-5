# %% [markdown]
# # IDA Pro File Path

# %%
dataPath = './ben_report/'
isSave = False
if isSave:
    resultPath = './ben_report_parsingResults/'

# %% [markdown]
# # Read the Assembly Files

# %%
import os
import json
import pickle
import tqdm

from pyparsing import Word, Optional, Suppress, alphas, alphanums, SkipTo, StringEnd, White

# %% [markdown]
# # Define Parser by Pyparsing Library

# %%
operandParser = Optional(Word(alphanums + ' []+-_.')('operand1')) + Optional(Suppress(White())) + Optional(Suppress(Word(',')) + Word(alphanums + ' []+-_.')('operand2')) + Optional(Suppress(Word(',')) + Word(alphanums + ' []+-_.')('operand3'))
parser = Word(alphas, alphanums)('mnemonic') + Optional(Suppress(Word(',') + White())) + operandParser
parser.ignore(';' + SkipTo(StringEnd()))
# Out:
# {{W:(ABCD..., ABCD...) [Suppress:({W:(,) <SP><TAB><CR><LF>})]} {{{[W:(ABCD...)] [Suppress:(<SP><TAB><CR><LF>)]} [{Suppress:(W:(,)) W:(ABCD...)}]} [{Suppress:(W:(,)) W:(ABCD...)}]}}

# %% [markdown]
# # Test Parser

# %%
with open(dataPath + os.listdir(dataPath)[0]) as jsonFilePointer:
    # load assembly code from JSON file
    jsonAsmFile = json.load(jsonFilePointer)
    asm = jsonAsmFile['asm']
            
    # parsing
    resultArray = []
    for function in asm[:2]:
        for basicBlock in function:
            for line in basicBlock:
                result = ['', '', '', '']
                for i, e in enumerate(parser.searchString(line)[0]):
                    if e.isdigit():
                        e = int(e)
                    elif e[-1] == 'h': # hexadecimal
                        try:
                            e = int(e[:-1], 16)
                        except:
                            pass
                                
                    result[i] = e
                        
                if result[0] == 'call':
                    result[1] = 'FTN'
                if result[0][0] == 'j':
                    result[1] = 'ADR'  
                    
                resultArray.append(result)
                print('[ Origin Code ] ', end='')
                print(line)
                
                print('[ Parsed Code ] ', end='')
                print(result)
                print()
                
    print('-------------------')
    print(resultArray)
# Out:
# [ Origin Code ] xor     eax, eax
# [ Parsed Code ] ['xor', 'eax', 'eax', '']
#
# [ Origin Code ] cmp     dword ptr [ecx], 1
# [ Parsed Code ] ['cmp', 'dword ptr [ecx]', 1, '']
#
# [ Origin Code ] setz    al
# [ Parsed Code ] ['setz', 'al', '', '']
#
# [ Origin Code ] retn
# [ Parsed Code ] ['retn', '', '', '']
#
# [ Origin Code ] sub     esp, 14h
# [ Parsed Code ] ['sub', 'esp', 20, '']
#
# [ Origin Code ] push    ebp
# [ Parsed Code ] ['push', 'ebp', '', '']
#
# [ Origin Code ] mov     ebp, [esp+18h+arg_0]
# [ Parsed Code ] ['mov', 'ebp', '[esp+18h+arg_0]', '']
#
# [ Origin Code ] push    esi
# [ Parsed Code ] ['push', 'esi', '', '']
#
# [ Origin Code ] push    edi
# [ Parsed Code ] ['push', 'edi', '', '']
#
# [ Origin Code ] mov     edi, ecx
# [ Parsed Code ] ['mov', 'edi', 'ecx', '']
#
# [ Origin Code ] lea     esi, [esp+20h+var_10]
# [ Parsed Code ] ['lea', 'esi', '[esp+20h+var_10]', '']
#
# [ Origin Code ] mov     ecx, ebp
# [ Parsed Code ] ['mov', 'ecx', 'ebp', '']
#
# [ Origin Code ] call    sub_100BF580
# [ Parsed Code ] ['call', 'FTN', '', '']
#
# [ Origin Code ] mov     esi, [esp+20h+var_10]
# [ Parsed Code ] ['mov', 'esi', '[esp+20h+var_10]', '']
#
# [ Origin Code ] cmp     esi, 2
# [ Parsed Code ] ['cmp', 'esi', 2, '']
#
# [ Origin Code ] jz      loc_1000118B
# [ Parsed Code ] ['jz', 'ADR', '', '']
#
# [ Origin Code ] mov     edi, [esp+20h+var_C]
# [ Parsed Code ] ['mov', 'edi', '[esp+20h+var_C]', '']
#
# [ Origin Code ] push    edi
# [ Parsed Code ] ['push', 'edi', '', '']
#
# [ Origin Code ] push    esi
# [ Parsed Code ] ['push', 'esi', '', '']
#
# [ Origin Code ] mov     eax, ebp
# [ Parsed Code ] ['mov', 'eax', 'ebp', '']
#
# [ Origin Code ] call    sub_10001BD0
# [ Parsed Code ] ['call', 'FTN', '', '']
#
# [ Origin Code ] add     esp, 8
# [ Parsed Code ] ['add', 'esp', 8, '']
#
# [ Origin Code ] test    al, al
# [ Parsed Code ] ['test', 'al', 'al', '']
#
# [ Origin Code ] jnz     loc_1000118B
# [ Parsed Code ] ['jnz', 'ADR', '', '']
#
# [ Origin Code ] cmp     esi, 1
# [ Parsed Code ] ['cmp', 'esi', 1, '']
#
# [ Origin Code ] jnz     short loc_1000114A
# [ Parsed Code ] ['jnz', 'ADR', '', '']
#
# [ Origin Code ] push    edi
# [ Parsed Code ] ['push', 'edi', '', '']
#
# [ Origin Code ] push    esi
# [ Parsed Code ] ['push', 'esi', '', '']
#
# [ Origin Code ] mov     ecx, ebp
# [ Parsed Code ] ['mov', 'ecx', 'ebp', '']
#
# [ Origin Code ] lea     eax, [esp+28h+var_8]
# [ Parsed Code ] ['lea', 'eax', '[esp+28h+var_8]', '']
#
# [ Origin Code ] call    sub_10001C00
# [ Parsed Code ] ['call', 'FTN', '', '']
#
# [ Origin Code ] mov     ecx, [ebx]
# [ Parsed Code ] ['mov', 'ecx', '[ebx]', '']
#
# [ Origin Code ] mov     byte ptr [esp+28h+var_10], 0
# [ Parsed Code ] ['mov', 'byte ptr [esp+28h+var_10]', 0, '']
#
# [ Origin Code ] mov     eax, [esp+28h+var_10]
# [ Parsed Code ] ['mov', 'eax', '[esp+28h+var_10]', '']
#
# [ Origin Code ] add     esp, 8
# [ Parsed Code ] ['add', 'esp', 8, '']
#
# [ Origin Code ] push    eax
# [ Parsed Code ] ['push', 'eax', '', '']
#
# [ Origin Code ] sub     esp, 0Ch
# [ Parsed Code ] ['sub', 'esp', 12, '']
#
# [ Origin Code ] mov     eax, esp
# [ Parsed Code ] ['mov', 'eax', 'esp', '']
#
# [ Origin Code ] mov     [eax], ecx
# [ Parsed Code ] ['mov', '[eax]', 'ecx', '']
#
# [ Origin Code ] mov     edx, [ebx+4]
# [ Parsed Code ] ['mov', 'edx', '[ebx+4]', '']
#
# [ Origin Code ] mov     [eax+4], edx
# [ Parsed Code ] ['mov', '[eax+4]', 'edx', '']
#
# [ Origin Code ] mov     ecx, [ebx+8]
# [ Parsed Code ] ['mov', 'ecx', '[ebx+8]', '']
#
# [ Origin Code ] mov     [eax+8], ecx
# [ Parsed Code ] ['mov', '[eax+8]', 'ecx', '']
#
# [ Origin Code ] mov     eax, [esp+30h+var_4]
# [ Parsed Code ] ['mov', 'eax', '[esp+30h+var_4]', '']
#
# [ Origin Code ] lea     edx, [esp+30h+var_10]
# [ Parsed Code ] ['lea', 'edx', '[esp+30h+var_10]', '']
#
# [ Origin Code ] push    edx
# [ Parsed Code ] ['push', 'edx', '', '']
#
# [ Origin Code ] mov     ecx, ebp
# [ Parsed Code ] ['mov', 'ecx', 'ebp', '']
#
# [ Origin Code ] call    sub_10001C10
# [ Parsed Code ] ['call', 'FTN', '', '']
#
# [ Origin Code ] add     esp, 14h
# [ Parsed Code ] ['add', 'esp', 20, '']
#
# [ Origin Code ] pop     edi
# [ Parsed Code ] ['pop', 'edi', '', '']
#
# [ Origin Code ] pop     esi
# [ Parsed Code ] ['pop', 'esi', '', '']
#
# [ Origin Code ] pop     ebp
# [ Parsed Code ] ['pop', 'ebp', '', '']
#
# [ Origin Code ] add     esp, 14h
# [ Parsed Code ] ['add', 'esp', 20, '']
#
# [ Origin Code ] retn
# [ Parsed Code ] ['retn', '', '', '']
#
# [ Origin Code ] mov     ecx, [ebx]
# [ Parsed Code ] ['mov', 'ecx', '[ebx]', '']
#
# [ Origin Code ] mov     byte ptr [esp+20h+var_10], 0
# [ Parsed Code ] ['mov', 'byte ptr [esp+20h+var_10]', 0, '']
#
# [ Origin Code ] mov     eax, [esp+20h+var_10]
# [ Parsed Code ] ['mov', 'eax', '[esp+20h+var_10]', '']
#
# [ Origin Code ] push    eax
# [ Parsed Code ] ['push', 'eax', '', '']
#
# [ Origin Code ] sub     esp, 0Ch
# [ Parsed Code ] ['sub', 'esp', 12, '']
#
# [ Origin Code ] mov     eax, esp
# [ Parsed Code ] ['mov', 'eax', 'esp', '']
#
# [ Origin Code ] mov     [eax], ecx
# [ Parsed Code ] ['mov', '[eax]', 'ecx', '']
#
# [ Origin Code ] mov     edx, [ebx+4]
# [ Parsed Code ] ['mov', 'edx', '[ebx+4]', '']
#
# [ Origin Code ] mov     [eax+4], edx
# [ Parsed Code ] ['mov', '[eax+4]', 'edx', '']
#
# [ Origin Code ] mov     ecx, [ebx+8]
# [ Parsed Code ] ['mov', 'ecx', '[ebx+8]', '']
#
# [ Origin Code ] mov     [eax+8], ecx
# [ Parsed Code ] ['mov', '[eax+8]', 'ecx', '']
#
# [ Origin Code ] push    edi
# [ Parsed Code ] ['push', 'edi', '', '']
#
# [ Origin Code ] push    esi
# [ Parsed Code ] ['push', 'esi', '', '']
#
# [ Origin Code ] mov     ecx, ebp
# [ Parsed Code ] ['mov', 'ecx', 'ebp', '']
#
# [ Origin Code ] lea     eax, [esp+38h+var_8]
# [ Parsed Code ] ['lea', 'eax', '[esp+38h+var_8]', '']
#
# [ Origin Code ] call    sub_10001CC0
# [ Parsed Code ] ['call', 'FTN', '', '']
#
# [ Origin Code ] mov     eax, [eax+4]
# [ Parsed Code ] ['mov', 'eax', '[eax+4]', '']
#
# [ Origin Code ] add     esp, 8
# [ Parsed Code ] ['add', 'esp', 8, '']
#
# [ Origin Code ] push    eax
# [ Parsed Code ] ['push', 'eax', '', '']
#
# [ Origin Code ] lea     edx, [esp+34h+var_10]
# [ Parsed Code ] ['lea', 'edx', '[esp+34h+var_10]', '']
#
# [ Origin Code ] push    ebp
# [ Parsed Code ] ['push', 'ebp', '', '']
#
# [ Origin Code ] push    edx
# [ Parsed Code ] ['push', 'edx', '', '']
#
# [ Origin Code ] call    sub_10001CD0
# [ Parsed Code ] ['call', 'FTN', '', '']
#
# [ Origin Code ] add     esp, 1Ch
# [ Parsed Code ] ['add', 'esp', 28, '']
#
# [ Origin Code ] pop     edi
# [ Parsed Code ] ['pop', 'edi', '', '']
#
# [ Origin Code ] pop     esi
# [ Parsed Code ] ['pop', 'esi', '', '']
#
# [ Origin Code ] pop     ebp
# [ Parsed Code ] ['pop', 'ebp', '', '']
#
# [ Origin Code ] add     esp, 14h
# [ Parsed Code ] ['add', 'esp', 20, '']
#
# [ Origin Code ] retn
# [ Parsed Code ] ['retn', '', '', '']
#
# -------------------
# [['xor', 'eax', 'eax', ''], ['cmp', 'dword ptr [ecx]', 1, ''], ['setz', 'al', '', ''], ['retn', '', '', ''], ['sub', 'esp', 20, ''], ['push', 'ebp', '', ''], ['mov', 'ebp', '[esp+18h+arg_0]', ''], ['push', 'esi', '', ''], ['push', 'edi', '', ''], ['mov', 'edi', 'ecx', ''], ['lea', 'esi', '[esp+20h+var_10]', ''], ['mov', 'ecx', 'ebp', ''], ['call', 'FTN', '', ''], ['mov', 'esi', '[esp+20h+var_10]', ''], ['cmp', 'esi', 2, ''], ['jz', 'ADR', '', ''], ['mov', 'edi', '[esp+20h+var_C]', ''], ['push', 'edi', '', ''], ['push', 'esi', '', ''], ['mov', 'eax', 'ebp', ''], ['call', 'FTN', '', ''], ['add', 'esp', 8, ''], ['test', 'al', 'al', ''], ['jnz', 'ADR', '', ''], ['cmp', 'esi', 1, ''], ['jnz', 'ADR', '', ''], ['push', 'edi', '', ''], ['push', 'esi', '', ''], ['mov', 'ecx', 'ebp', ''], ['lea', 'eax', '[esp+28h+var_8]', ''], ['call', 'FTN', '', ''], ['mov', 'ecx', '[ebx]', ''], ['mov', 'byte ptr [esp+28h+var_10]', 0, ''], ['mov', 'eax', '[esp+28h+var_10]', ''], ['add', 'esp', 8, ''], ['push', 'eax', '', ''], ['sub', 'esp', 12, ''], ['mov', 'eax', 'esp', ''], ['mov', '[eax]', 'ecx', ''], ['mov', 'edx', '[ebx+4]', ''], ['mov', '[eax+4]', 'edx', ''], ['mov', 'ecx', '[ebx+8]', ''], ['mov', '[eax+8]', 'ecx', ''], ['mov', 'eax', '[esp+30h+var_4]', ''], ['lea', 'edx', '[esp+30h+var_10]', ''], ['push', 'edx', '', ''], ['mov', 'ecx', 'ebp', ''], ['call', 'FTN', '', ''], ['add', 'esp', 20, ''], ['pop', 'edi', '', ''], ['pop', 'esi', '', ''], ['pop', 'ebp', '', ''], ['add', 'esp', 20, ''], ['retn', '', '', ''], ['mov', 'ecx', '[ebx]', ''], ['mov', 'byte ptr [esp+20h+var_10]', 0, ''], ['mov', 'eax', '[esp+20h+var_10]', ''], ['push', 'eax', '', ''], ['sub', 'esp', 12, ''], ['mov', 'eax', 'esp', ''], ['mov', '[eax]', 'ecx', ''], ['mov', 'edx', '[ebx+4]', ''], ['mov', '[eax+4]', 'edx', ''], ['mov', 'ecx', '[ebx+8]', ''], ['mov', '[eax+8]', 'ecx', ''], ['push', 'edi', '', ''], ['push', 'esi', '', ''], ['mov', 'ecx', 'ebp', ''], ['lea', 'eax', '[esp+38h+var_8]', ''], ['call', 'FTN', '', ''], ['mov', 'eax', '[eax+4]', ''], ['add', 'esp', 8, ''], ['push', 'eax', '', ''], ['lea', 'edx', '[esp+34h+var_10]', ''], ['push', 'ebp', '', ''], ['push', 'edx', '', ''], ['call', 'FTN', '', ''], ['add', 'esp', 28, ''], ['pop', 'edi', '', ''], ['pop', 'esi', '', ''], ['pop', 'ebp', '', ''], ['add', 'esp', 20, ''], ['retn', '', '', '']]

# %% [markdown]
# # Parsing

# %%
for fileName in tqdm.tqdm(os.listdir(dataPath)):
    filePath = dataPath + fileName
    if os.path.isfile(filePath):
        with open(filePath) as jsonFilePointer:
            # load assembly code from JSON file
            jsonAsmFile = json.load(jsonFilePointer)
            asm = jsonAsmFile['asm']
            
            # parsing
            resultArray = []
            for function in asm:
                for basicBlock in function:
                    for line in basicBlock:
                        result = ['', '', '', '']
                        for i, e in enumerate(parser.searchString(line)[0]):
                            if e.isdigit():
                                e = int(e)
                            elif e[-1] == 'h': # hexadecimal
                                try:
                                    e = int(e[:-1], 16)
                                except:
                                    pass
                                
                            result[i] = e
                        
                        if result[0] == 'call':
                            result[1] = 'FTN'
                        if result[0][0] == 'j':
                            result[1] = 'ADR'
                            
                        resultArray.append(result)
                        
            # save result
            if isSave:
                with open(resultPath + fileName[:-5] + '.pickle', 'wb') as resultFilePointer:
                    pickle.dump(resultArray, resultFilePointer)
